# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
def img_svmpoly():
    
    label_list = ['C=1e-3','C=1e-2','C=1e-1','C=1e-0','C=1e1','C=1e2','C=1e3']  
    num_list1 = [85.85,93.9,98.95,99.91,100,100,100] #  
    num_list2 = [83.98,87.51,88.26,87.88,87.47,87.08,87.08] #  
    
    x = range(len(num_list1)) 

    rects1 = plt.bar(left=x, height=num_list1, width=0.45, alpha=0.8, color='red',label="training data") 
    rects2 = plt.bar(left=[i + 0.45 for i in x], height=num_list2, width=0.45, color='navy',label="validation data") 

    plt.ylim(0,120) # 
 
    plt.xticks([index + 0.2 for index in x], label_list) 
    plt.xlabel("\nAccuracy",fontsize = 20) 
    plt.title("FashionMNIST SVM: gamma = 1e-6, kernel = poly\n",fontsize = 20) 
    plt.legend() 
    for rect in rects1: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    for rect in rects2: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(10, 8)
    plt.show()

# %%
img_svmpoly()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
def img_svmrbf():
    
    label_list = ['C=1e-2','C=1e-1','C=1e-0','C=1e1','C=1e2','C=1e3'] #  
    num_list1 = [64.85,84.41,97.81,100,100,100] #  
    num_list2 = [64.32,81.93,89.53,89.31,89.31,89.57] #  
    
    x = range(len(num_list1)) 

    rects1 = plt.bar(left=x, height=num_list1, width=0.45, alpha=0.8, color='green',label="training data") 
    rects2 = plt.bar(left=[i + 0.45 for i in x], height=num_list2, width=0.45, color='lightgreen',label="validation data") 

    plt.ylim(0,120) #
 
    plt.xticks([index + 0.2 for index in x], label_list) 
    plt.xlabel("\nAccuracy",fontsize = 20) 
    plt.title("FashionMNIST SVM: gamma = 1e-6, kernel = rbf\n",fontsize = 20) 
    plt.legend() 
    for rect in rects1: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    for rect in rects2: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(10, 8)
    plt.show()

# %%
img_svmrbf()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
def img_mlp1():
    
    label_list = ['[16]','[32]','[64]','[128]','[256]','[512]','[1024]','[1024,1024]','[1024,512]','[1024,256]'] #  
    num_list1 = [62.25,74.23,83.24,86.71,88.85,88.75,91.06,88.85,90.69,89.02] #  
    num_list2 = [62.03,73.09,81.71,84.11,85.47,85.18,86.68,85.02,86.32,86.27] #  
    
    x = range(len(num_list1)) 

    rects1 = plt.bar(left=x, height=num_list1, width=0.45, alpha=0.8, color='orange',label="training data") 
    rects2 = plt.bar(left=[i + 0.45 for i in x], height=num_list2, width=0.45, color='lightskyblue',label="validation data") 

    plt.ylim(0,100) # 

    plt.xticks([index + 0.2 for index in x], label_list) 
    plt.xlabel("\nhidden layses with neurons",fontsize = 20) 
    plt.title("FashionMNIST MLP part 1\n",fontsize = 20) 
    plt.legend() 
    for rect in rects1: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    for rect in rects2: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(18.5, 7)
    plt.show()

# %%
img_mlp1()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
def img_mlp2():
    
    label_list = ['[1024,128]','[1024,64]','[1024,32]','[512,512]','[512,256]','[512,128]','[512,64]','[256,256]','[256,128]','[256,64]'] #  
    num_list1 = [90.20,70.01,60.09,89.44,91.15,89.11,76.73,84.94,89.47,88.53] #  
    num_list2 = [86.62,69.24,59.23,85.06,86.74,85.03,75.85,82.57,85.43,85.88] #  
    
    x = range(len(num_list1)) 

    rects1 = plt.bar(left=x, height=num_list1, width=0.45, alpha=0.8, color='orange',label="training data") 
    rects2 = plt.bar(left=[i + 0.45 for i in x], height=num_list2, width=0.45, color='lightskyblue',label="validation data") 

    plt.ylim(0,100)  

    plt.xticks([index + 0.2 for index in x], label_list) 
    plt.xlabel("\nhidden layses with neurons",fontsize = 20) 
    plt.title("FashionMNIST MLP part 2\n",fontsize = 20) 
    plt.legend() 
    for rect in rects1: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    for rect in rects2: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(18.5, 7)
    plt.show()

# %%
img_mlp2()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
def img_mlp3():
    
    label_list = ['[128,128]','[128,64]','[128,32]','[64,64]','[64,32]','[64,16]','[32,32]','[32,16]']  
    num_list1 = [88.05,87.07,82.83,85.49,88.13,72.78,75.87,86.82] #  
    num_list2 = [84.73,84.75,81.70,83.62,85.88,71.74,75.16,84.97] #  
    
    x = range(len(num_list1)) 

    rects1 = plt.bar(left=x, height=num_list1, width=0.45, alpha=0.8, color='orange',label="training data") 
    rects2 = plt.bar(left=[i + 0.45 for i in x], height=num_list2, width=0.45, color='lightskyblue',label="validation data") 

    plt.ylim(0,100) 

    
    plt.xticks([index + 0.2 for index in x], label_list) 
    plt.xlabel("\nhidden layses with neurons",fontsize = 20) 
    plt.title("FashionMNIST MLP part 3\n",fontsize = 20) 
    plt.legend() 
    for rect in rects1: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    for rect in rects2: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(18.5, 7)
    plt.show()

# %%
img_mlp3()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
acc_train_poly = [76.15,76.42,76.02,76.08,76.15,76.15,75.87] #  
acc_valid_poly = [75.39,75.71,75.69,75.36,75.39,75.39,76.03] #  
pre_train_poly = [58,58,58,61,58,58,58] #  
pre_valid_poly = [57,57,57,64,57,57,58] # 
rec_train_poly = [76,76,76,76,76,76,76] #  
rec_valid_poly = [75,76,76,75,75,75,76] # 
f1_train_poly = [66,66,66,66,66,66,65] #  
f1_valid_poly = [65,65,65,65,65,65,65] #

# %%
def img_svmpoly_income(value1,value2,type,y1,y2,kernel):
    
    label_list = ['C=1e-3','C=1e-2','C=1e-1','C=1e-0','C=1e1','C=1e2','C=1e3'] #  
    
    
    x = range(len(value1)) 

    rects1 = plt.bar(left=x, height=value1, width=0.45, alpha=0.8, color='green',label="training data") 
    rects2 = plt.bar(left=[i + 0.45 for i in x], height=value2, width=0.45, color='lightgreen',label="validation data") 
 

    plt.ylim(y1,y2) # 

    plt.xticks([index + 0.2 for index in x], label_list) 
    plt.xlabel('\n'+type,fontsize=20) 
    plt.title("Income Predict SVM: gamma = 1e-6, kernel = "+kernel+'\n',fontsize=20) 
    plt.legend() 
    for rect in rects1: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    for rect in rects2: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(10,8)
    plt.show()

# %%
img_svmpoly_income(acc_train_poly,acc_valid_poly,"Accurancy",0,100,'poly')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_svmpoly_income(pre_train_poly,pre_valid_poly,"Precision",0,75,'poly')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_svmpoly_income(rec_train_poly,rec_valid_poly,"Recall",0,90,'poly')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_svmpoly_income(f1_train_poly,f1_valid_poly,"F1_Score",0,80,'poly')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
acc_train_rbf = [76.02,75.82,76.15,76.15,75.87,76.69,72.56]
acc_valid_rbf = [75.69,74.99,75.39,75.39,76.03,76.43,71.48]
pre_train_rbf = [58,62,58,58,58,82,63]
pre_valid_rbf = [57,62,57,57,58,82,62]
rec_train_rbf = [76,76,76,76,76,77,73]
rec_valid_rbf = [76,75,75,75,76,76,71]
f1_train_rbf = [66,66,66,66,65,67,66]
f1_valid_rbf = [65,65,65,65,66,67,65]

# %%
img_svmpoly_income(acc_train_rbf,acc_valid_rbf,"Accuracy",0,100,'rbf')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_svmpoly_income(pre_train_rbf,pre_valid_rbf,"Precision",0,95,'rbf')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_svmpoly_income(rec_train_rbf,rec_valid_rbf,"Recall",0,90,'rbf')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_svmpoly_income(f1_train_rbf,f1_valid_rbf,"F1_Score",0,80,'rbf')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
def img_mlp_income(label_list,value1,value2,n,type):
    
  
    x = range(len(value1)) 

    rects1 = plt.bar(left=x, height=value1, width=0.45, alpha=0.8, color='orange',label="training data") 
    rects2 = plt.bar(left=[i + 0.45 for i in x], height=value2, width=0.45, color='lightskyblue',label="validation data") 

    plt.ylim(0,100) 
 
    plt.xticks([index + 0.2 for index in x], label_list) 
    plt.xlabel("\nHidden layses with neurons \n"+type,fontsize = 20) 
    plt.title("Income Predict MLP part"+str(n)+"\n",fontsize = 20) 
    plt.legend() 
    for rect in rects1: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    for rect in rects2: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(18.5, 7)
    plt.show()

# %%
label_list_mlp1 = ['[4]','[8]','[16]','[32]','[32,32]','[32,16]','[32,8]','[32,4]','[16,16]','[16,8]','[16,4]'] # 横坐标刻度显示值
acc_train_mlp1 = [75.04,84.81,84.81,79.40,83.27,83.58,85.33,84.98,79.51,81.54,81.78]
acc_valid_mlp1 = [74.41,84.41,84.47,79.23,83.57,83.85,84.50,84.66,79.45,81.37,81.83]
pre_train_mlp1 = [65,84,84,78,83,83,85,84,78,80,80,85]
acc_valid_mlp1 = [64,84,84,78,83,83,84,84,79,80,81]
rec_train_mlp1 = [75,85,85,79,83,84,85,85,80,82,82]
rec_valid_mlp1 = [74,84,84,79,84,84,85,85,79,81,82]
f1_train_mlp1 = [67,84,84,75,83,83,85,84,75,80,80]
f1_valid_mlp1 = [65,84,84,75,83,83,84,84,75,80,81]

# %%
img_mlp_income(label_list_mlp1,acc_train_mlp1,acc_train_mlp1,1,'Accuracy')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_mlp_income(label_list_mlp1,pre_train_mlp1,pre_train_mlp1,1,'Precision')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_mlp_income(label_list_mlp1,rec_train_mlp1,rec_train_mlp1,1,'Recall')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_mlp_income(label_list_mlp1,f1_train_mlp1,f1_train_mlp1,1,'F1_score')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
label_list_mlp2 = ['[8,8]','[8,4]','[4,4]','[32,32,32]','[16,16,16]','[8,8,8]','[4,4,4]','[32,16,8]','[32,16,8,4]'] # 横坐标刻度显示值
acc_train_mlp2 = [84.76,78.83,76.15,83.88,85.13,84.61,76.15,76.14,83.19]
acc_valid_mlp2 = [84.33,78.73,75.39,83.46,84.55,84.23,75.83,75.39,82.89]
pre_train_mlp2 = [84,77,58,83,84,84,70,58,82]
acc_valid_mlp2 = [84,78,57,83,84,83,75,57,82]
rec_train_mlp2 = [85,79,76,84,85,85,76,76,83]
rec_valid_mlp2 = [84,79,75,83,85,84,76,75,83]
f1_train_mlp2 = [84,74,66,83,85,84,66,66,82]
f1_valid_mlp2 = [84,74,65,83,84,84,65,65,81]

# %%
img_mlp_income(label_list_mlp2,acc_train_mlp2,acc_train_mlp2,2,'Accuracy')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_mlp_income(label_list_mlp2,pre_train_mlp2,pre_train_mlp2,2,'Precision')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_mlp_income(label_list_mlp2,rec_train_mlp2,rec_train_mlp2,2,'Recall')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
img_mlp_income(label_list_mlp2,f1_train_mlp2,f1_train_mlp2,2,'F1_Score')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %% [markdown]
# ### the three best

# %% [markdown]
# ## Learning Curve

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import svm
from sklearn.model_selection import validation_curve,learning_curve

# %%
import utils.mnist_reader as mnist_reader
from utils import mnist_reader
XM_train, YM_train = mnist_reader.load_mnist('data-FM/fashion', kind='train')
XM_test, YM_test = mnist_reader.load_mnist('data-FM/fashion', kind='t10k')

# divide training data to two parts, one for training, and the other is for validation, then, normalized the datas.

inds = np.arange(len(XM_train))
np.random.seed(5)
np.random.shuffle(inds)
features = np.array(XM_train[train_inds,:])
labels = np.array(YM_train[train_inds])
print('features:',np.shape(features))
print('labels:',np.shape(labels))
# Out:
# features: (42000, 784)
# labels: (42000,)

# %%
print(len(features))
size_grid = np.array(np.arange(1,11)/10)
RF = svm.SVC(kernel = 'rbf',  C = 1e3,  gamma = 1e-6 )
train_size,train_scores,validation_scores = learning_curve(RF,features,labels,train_sizes = size_grid, cv = 3)
print('######Learning Curve')
print('train_score\n',train_scores)
print('validation_score\n',validation_scores)

plt.figure()
plt.plot(size_grid,np.average(train_scores, axis = 1), 'o-',color = 'red',label = 'training')
plt.plot(size_grid, np.average(validation_scores, axis = 1), 'o-',color = 'black', label = 'validation')
plt.title('Learning Curve')
plt.xlabel('sample size')
plt.ylabel('accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.svm import LinearSVC
from sklearn.learning_curve import learning_curve



def plot_learning_curve(estimator, title, X, y,ylim=None, cv=3,
                        train_sizes=np.linspace(.1, 1.0, 5)):

    plt.figure()
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=3, n_jobs=1, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    plt.legend(loc="best")
    plt.grid("on") 
    if ylim:
        plt.ylim(ylim)
    plt.title(title)
    plt.show()


plot_learning_curve(svm.SVC(kernel = 'rbf',  C = 1e3,  gamma = 1e-6 ), "RBF",
                    features, labels, ylim=(0.8, 1.01),
                    train_sizes=np.linspace(.05, 0.2, 5))
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
num_list1 = [58.49,66.51,71.62]  
num_list2 = [58.09,67.22,71.89]
num_list3 = [79.8,78.29,72.56]  
num_list4 = [78.96,78.2,72.84]

def img_nb(value1,value2,type):
    
    label_list = ['Gaussian','Multinomial','Bernoulli']  
    
    
    x = range(len(value1)) 

    rects1 = plt.bar(left=x, height=value1, width=0.45, alpha=0.8, color='red',label="training data") 
    rects2 = plt.bar(left=[i + 0.45 for i in x], height=value2, width=0.45, color='navy',label="validation data") 
 

    plt.ylim(40,95) 
 
    plt.xticks([index + 0.2 for index in x], label_list) 
    plt.xlabel('type of Naive Bayes',fontsize=10) 
    plt.ylabel('Accuracy(%)',fontsize=12)
    plt.title("Naive Bayes on "+type,fontsize=12) 
    plt.legend() 
    for rect in rects1: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    for rect in rects2: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(10,4)
#    plt.show()


flt=plt.figure(figsize=(12,2))
flt.add_subplot(121)
img_nb(num_list1,num_list2,'Fashion-MNIST')
flt.add_subplot(122)
img_nb(num_list3,num_list4,'Adult Income')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
def curve_svm_f():
    
    #label_list = ['C=1e-3','C=1e-2','C=1e-1','C=1e-0','C=1e1','C=1e2','C=1e3']  
    num_list1 = [85.85,93.9,98.95,99.91,100,100,100] # training data, poly 
    num_list2 = [83.98,87.51,88.26,87.88,87.47,87.08,87.08] # validation data, poly  
    num_list3 = [10.20,64.85,84.41,97.81,100,100,100] # training data, rbf  
    num_list4 = [9.79,64.32,81.93,89.53,89.31,89.31,89.57] # validation data, rbf  

    x = range(len(num_list1)) 
    
    plt.plot(x,num_list1,'o-',color='r',label = 'training data - poly')
    plt.plot(x,num_list2,'o--',color='r',label = 'validation data - poly')
    plt.plot(x,num_list3,'o-',color='navy',label = 'training data - rbf')
    plt.plot(x,num_list4,'o--',color='navy',label = 'validation data - rbf')
    
    plt.xticks(np.arange(7),('1e-3','1e-2','1e-1','1e-0','1e1','1e2','1e3'))
    plt.xlabel("C",fontsize = 10)
    plt.ylabel('Accuracy(%)',fontsize=12)
    plt.title("Fashion-MNIST SVM: gamma = 1e-6",fontsize = 12) 
    plt.legend() 
    plt.grid()
     
#    fig = matplotlib.pyplot.gcf()
#    fig.set_size_inches(10, 8)
#    plt.show()

# %%
curve_svm_f()

# %%
def curve_svm_i():
    
    #label_list = ['C=1e-3','C=1e-2','C=1e-1','C=1e-0','C=1e1','C=1e2','C=1e3']  
    num_list1 = [76.15,76.42,76.02,76.08,76.15,76.15,75.87] # 纵坐标值 
    num_list2 = [75.39,75.71,75.69,75.36,75.39,75.39,76.03]
    num_list3 = [76.02,75.82,76.15,76.15,75.87,76.69,72.56]
    num_list4 = [75.69,74.99,75.39,75.39,76.03,76.43,71.48]
 

    x = range(len(num_list1)) 
    
#    plt.axis([0,8,50,80])
    plt.plot(x,num_list1,'o-',color='r',label = 'training data - poly')
    plt.plot(x,num_list2,'o--',color='r',label = 'validation data - poly')
    plt.plot(x,num_list3,'o-',color='navy',label = 'training data - rbf')
    plt.plot(x,num_list4,'o--',color='navy',label = 'validation data - rbf')
    plt.xticks(np.arange(7),('1e-3','1e-2','1e-1','1e-0','1e1','1e2','1e3'))
    plt.ylabel('Accuracy(%)',fontsize = 12)
    plt.xlabel("C",fontsize = 10) 
    plt.title("Adult Income SVM: gamma = 1e-6",fontsize = 12) 
    plt.legend() 
    plt.grid()
#    fig = matplotlib.pyplot.gcf()
#    fig.set_size_inches(10, 8)
#    plt.show()

# %%
curve_svm_i()

# %%
flt=plt.figure(figsize=(12,3))
flt.add_subplot(121)
curve_svm_f()
flt.add_subplot(122)
curve_svm_i()

# %%
def curve_mlp_f():
    
    #label_list = ['[1024]','[512]','[256]','[128]','[64]','[32]','[16]'] #  
    x1 = np.arange(1,8)
    num_list1 = [90.99,89.49,88.8,77.8,81.7,79.65,53.28] #  
    num_list2 = [87.13,85.93,85.11,76.79,79.66,77.96,52.65] # 
    
    #label_list = ['[1024,1024]','[1024,512]','[1024,256]','[1024,128]','[1024,64]','[1024,32]','[1024,16]'] #  
    x2 = np.arange(1,8)
    num_list3 = [89.35,88.08,90,85.83,72.41,10.06,9.95] #  
    num_list4 = [85.26,85.32,86.43,84.30,71.42,9.9,10.13] #  
    
    #label_list = ['[512,512]','[512,256]','[512,128]','[512,64]','[512,32]','[512,16]']
    x3 = np.arange(2,8)
    num_list5 = [88.75,89.14,81.37,85.34,66.02,33.65]
    num_list6 = [85.47,85.32,79.94,84.06,65.22,32.83]
    
    label_list = ['[256,256]','[256,128]','[256,64]','[256,32]','[256,16]']
    x4 = np.arange(3,8)
    num_list7 = [88.17,88.18,88.23,87.1,87.11]
    num_list8 = [84.17,84.64,86.21,84.63,84.74]
    
    label_list = ['[128,128]','[128,64]','[128,32]','[128,16]'] #  
    x5 = np.arange(4,8)
    num_list9 = [85.07,88.93,81.16,87.99] #  
    num_list10 = [82.52,85.67,79.61,85.85] #  
   
    
    label_list = ['[64,64]','[64,32]','[64,16]'] #  
    x6 = np.arange(5,8)
    num_list11 = [85,87.69,85.94] #  
    num_list12 = [83.11,85.62,83.64] #  
    
    label_list = ['[32,32]','[32,16]']
    x7 = np.arange(6,8)
    num_list13 = [86.10,85.77]
    num_list14 = [83.712,83.92]
    
    plt.plot(x1,num_list1,'o-',color='r',label = 'training data - one hidden layer')
    plt.plot(x1,num_list2,'o--',color='r',label = 'validation data - one hidden layer')
    plt.plot(x2,num_list3,'o-',color='g',label = 'training data - two hidden layers (1024,-)')
    plt.plot(x2,num_list4,'o--',color='g',label = 'validation data - two hidden layers (1024,-)')
    plt.plot(x3,num_list5,'o-',color='b',label = 'training data - two hidden layers (512,-)')
    plt.plot(x3,num_list6,'o--',color='b',label = 'validation data - two hidden layers (512,-)')    
    plt.plot(x4,num_list7,'o-',color='c',label = 'training data - two hidden layers (256,-)')
    plt.plot(x4,num_list8,'o--',color='c',label = 'validation data - two hidden layers (256,-)')
    plt.plot(x5,num_list9,'o-',color='navy',label = 'training data - two hidden layers (128,-)')
    plt.plot(x5,num_list10,'o--',color='navy',label = 'validation data - two hidden layers (128,-)')
    plt.plot(x6,num_list11,'o-',color='gray',label = 'training data - two hidden layers (64,-)')
    plt.plot(x6,num_list12,'o--',color='gray',label = 'validation data - two hidden layers (64,-)')
    plt.plot(x7,num_list13,'o-',color='black',label = 'training data - two hidden layers (32,-)')
    plt.plot(x7,num_list14,'o--',color='black',label = 'validation data - two hidden layers (32,-)')
    
    plt.xticks(np.arange(1,8),('1024','512','256','128','64','32','16'))
    plt.ylabel('Accuracy(%)',fontsize = 12) 
    plt.xlabel('number of features in last hidden layer(s)',fontsize = 10)
    plt.title("Fashion-MNIST",fontsize = 12) 
    plt.legend() 
     
    fig = matplotlib.pyplot.gcf()
#    fig.set_size_inches(18,6)
    plt.grid()
    #plt.show()

# %%
curve_mlp_f()

# %%
def curve_mlp_i():
    
    #label_list = ['[1024]','[512]','[256]','[128]','[64]','[32]','[16]'] #  
    x1 = np.arange(18)
    num_list1 = [23.84,23.85,79.03,78.97,76.15,77.52,76.62,76.15,78.12,79.02,79.23,78.09,79.46,79.47,76.54,76.14,79.46,79.49] # 纵坐标值1 
    num_list2 = [24.6,24.61,79.03,78.79,75.39,76.87,75.94,75.39,77.54,78.86,79.06,77.57,79.2,79.08,75.83,75.39,79.12,79.23] # 纵坐标值2
    
    
    
    plt.plot(x1,num_list1,'o-',label = 'training data')
    plt.plot(x1,num_list2,'o--',label = 'validation data')
    
    plt.xticks(np.arange(18),('[2]','[4]','[8]','[16]','[2,2]','[4,2]','[8,2]','[16,2]','[4,4]','[8,4]','[16,4]','[8,8]','[16,8]','[16,16]','[2,2,2]','[4,4,4]','[8,8,8]','[16,16,16]'))
    plt.ylabel('Accuracy(%)',fontsize = 12) 
    plt.xlabel('number of features in hidden layer(s)',fontsize = 10)
    plt.title("Adult Income",fontsize = 12) 
    plt.legend() 
     
    fig = matplotlib.pyplot.gcf()
 #   fig.set_size_inches(18,5)
    plt.grid()
    #plt.show()

# %%
curve_mlp_i()

# %%
flt=plt.figure(figsize=(15,18))
flt.add_subplot(311)
curve_mlp_f()
flt.add_subplot(312)
curve_mlp_i()

# %%
num_list1 = [71.62,89.16,85.75]  
label_list1 = ['Bernoulli','SVM-RBF C=1000 gamma=1e-6','MLP - [1024]']
num_list3 = [79.63,74.12,79.48]  
label_list2 = ['Gaussian','SVM-RBF C=100 gamma=1e-6','MLP - [16,16,16]']

def img_best(label_list,value1,value2,type,y1,y2):
    
      
    
    
    x = range(len(value1)) 

    rects1 = plt.bar(left=x, height=value1, width=0.45, alpha=0.8, color='red',label="training data") 
 

    plt.ylim(y1,y2) 

    
    plt.xticks([index + 0.2 for index in x], label_list) 
    plt.xlabel('Type of model',fontsize=15) 
    plt.ylabel('Accuracy(%)',fontsize=15)
    plt.title("Best model on "+type,fontsize=15) 
    plt.legend() 
    for rect in rects1: 
        height = rect.get_height() 
        plt.text(rect.get_x() + rect.get_width() / 2, height+1, str(height), fontsize=10,ha="center", va="bottom") 
    
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(15,4)
#    plt.show()


flt=plt.figure(figsize=(20,5))
flt.add_subplot(121)
img_best(label_list1,num_list1,num_list2,'FashionMNIST',50,110)
flt.add_subplot(122)
img_best(label_list2,num_list3,num_list4,'Adult Income',50,95)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1855: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)

# %%
def img_best():
    result = [79.48,74.12,79.63,85.75,89.16,70.55]  
    plt.barh(range(6), result, height=0.7, color='steelblue', alpha=0.8) 
     
    plt.yticks(range(6), ['MLP on Adult Income','SVM on Adult Income','Naive Bayes on Adult Income','MLP on Fashion-MNIST','SVM on Fashion-MNIST','Naive Bayes on Fashion-MNIST']) 
    plt.xlim(0,100) 
    plt.xlabel('Accuracy(%)') 
    plt.ylabel("Type of model on two datasets")
    plt.title("Result of best model on two datasets") 
    for x, y in enumerate(result): 
        plt.text(y + 0.2, x - 0.1, '%s' % str(int(float(y)*100)/100)) 
    plt.show()

# %%
img_best()
